# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import functools

# %% [markdown]
# # Informacion hoteles por isla

# %%
maestro_cm28 = "../../../datos/CM28/maestro_cm28.csv"
maestro_cm28 = pd.read_csv(maestro_cm28)
maestro_cm28.describe()
# Out:
#               Anyo        Plazas  Plazas_por_isla  Perc_Plazas  \
# count  8810.000000   8810.000000      8810.000000  8810.000000
# mean   2009.956981    961.665721     88298.601022     1.589012
# std       5.873266   2791.033843     58396.588013     3.477609
# min    2000.000000      0.000000       979.000000     0.000000
# 25%    2005.000000     22.000000     11096.000000     0.030000
# 50%    2010.000000     76.000000    129343.000000     0.240000
# 75%    2015.000000    500.000000    135170.000000     1.220000
# max    2019.000000  32170.000000    172032.000000    33.540000
#
#        Establecimientos  Alojativos_por_isla  Perc_Establecimientos  \
# count       8810.000000          8810.000000            8810.000000
# mean          13.886266          1347.176958               1.588839
# std           72.130758          2002.922318               3.810312
# min            1.000000            80.000000               0.010000
# ...

# %%
maestro_cm28.groupby(['Isla','Municipio','Modalidad']).count()
# Out:
#                                                    Unnamed: 0  Anyo  \
# Isla      Municipio                 Modalidad
# El Hierro Frontera                  Extrahotelera         109   109
#                                     Hotelera               60    60
#           Pinar de El Hierro (El)   Extrahotelera          56    56
#                                     Hotelera               21    21
#           Valverde                  Extrahotelera          80    80
# ...                                                       ...   ...
# Tenerife  Tegueste                  Extrahotelera          25    25
#                                     Hotelera                3     3
#           Victoria De Acentejo (La) Extrahotelera          24    24
#           Vilaflor                  Extrahotelera          25    25
#                                     Hotelera               91    91
#
#                                                    Clasificacion  Plazas  \
# ...

# %% [markdown]
# ## clasificacion de hoteles

# %%
clasificacion   = maestro_cm28.groupby(['Isla','Municipio','Modalidad','Clasificacion'])['Plazas','Alojativos_por_isla']
clasificacion.describe().loc[:,(slice(None),['count','min','max'])]
# Out:
# /tmp/ipykernel_49435/1153159040.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   clasificacion   = maestro_cm28.groupby(['Isla','Municipio','Modalidad','Clasificacion'])['Plazas','Alojativos_por_isla']
#                                                    Plazas               \
#                                                     count   min    max
# Isla      Municipio Modalidad     Clasificacion
# El Hierro Frontera  Extrahotelera 1 llave            20.0  99.0  177.0
#                                   2 llaves           20.0  91.0   91.0
#                                   4 llaves           15.0   4.0    4.0
#                                   Categoría única    20.0  31.0  418.0
#                                   Cinco estrellas     7.0   4.0    4.0
# ...                                                   ...   ...    ...
# Tenerife  Vilaflor  Hotelera      1 palmera          20.0  40.0   40.0
# ...

# %%
clasificacion= maestro_cm28.groupby(['Isla','Municipio','Modalidad','Clasificacion'])['Perc_Establecimientos']
clasificacion.describe()
# Out:
#                                                     count       mean  \
# Isla      Municipio Modalidad     Clasificacion
# El Hierro Frontera  Extrahotelera 1 llave            20.0   4.673000
#                                   2 llaves           20.0   2.937500
#                                   4 llaves           15.0   0.616000
#                                   Categoría única    20.0  14.270500
#                                   Cinco estrellas     7.0   0.401429
# ...                                                   ...        ...
# Tenerife  Vilaflor  Hotelera      1 palmera          20.0   0.133000
#                                   Cuatro estrellas   16.0   0.122500
#                                   Dos estrellas      15.0   0.119333
#                                   Tres estrellas     20.0   0.133000
#                                   Una estrella       20.0   0.133000
#
#                                                          std    min      25%  \
# ...
