# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import functools

# %% [markdown]
# # actividades economicas por zonas / islas

# %%
maestro_cm23 = "../../../datos/CM23/maestro_cm23.csv"
maestro_cm23 = pd.read_csv(maestro_cm23)
maestro_cm23.describe()
# Out:
# /home/franz96521/miniconda3/envs/datathon/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (1,2,3,4,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                 anyo            mes          valor      valorprev  \
# count  397019.000000  397019.000000  397019.000000  237046.000000
# mean     2018.981792       5.020601     120.998887     133.117036
# std         0.812208       2.611414     539.986533     547.008301
# min      2018.000000       1.000000       1.000000       1.000000
# 25%      2018.000000       3.000000       3.000000       4.000000
# 50%      2019.000000       5.000000      11.000000      15.000000
# 75%      2020.000000       7.000000      50.000000      62.000000
# max      2020.000000      12.000000   16946.000000   15101.000000
#
#        codigo_actividad  ultima_fecha
# count       5479.000000      397019.0
# ...

# %%
maestro_cm23
# Out:
#         Unnamed: 0       isla     sexo  \
# 0                0  EL HIERRO  HOMBRES
# 1                1  EL HIERRO  HOMBRES
# 2                2  EL HIERRO  HOMBRES
# 3                3  EL HIERRO  HOMBRES
# 4                4  EL HIERRO  HOMBRES
# ...            ...        ...      ...
# 397014      397014   TENERIFE      NaN
# 397015      397015   TENERIFE      NaN
# 397016      397016   TENERIFE      NaN
# 397017      397017   TENERIFE      NaN
# 397018      397018   TENERIFE      NaN
#
#                                                 actividad           edad  \
# 0       ACTIVIDADES ADMINISTRATIVAS Y SERVICIOS AUXILI...       45 o mas
# 1       ACTIVIDADES ADMINISTRATIVAS Y SERVICIOS AUXILI...  Entre 25 y 45
# 2       ACTIVIDADES ADMINISTRATIVAS Y SERVICIOS AUXILI...    Menor de 25
# 3       ACTIVIDADES PROFESIONALES, CIENTIFICAS Y TECNICAS  Entre 25 y 45
# 4          ACTIVIDADES SANITARIAS Y DE SERVICIOS SOCIALES       45 o mas
# ...

# %%
maestro_cm23.groupby(['isla','comarca', 'mes','actividad']).size()
# Out:
# isla       comarca    mes  actividad
# EL HIERRO  EL HIERRO  1    ACTIVIDADES ADMINISTRATIVAS Y SERVICIOS AUXILIARES                                                                                                      33
#                            ACTIVIDADES ARTISTICAS RECREATIVAS Y DE ENTRETENIMIENTO                                                                                                 17
#                            ACTIVIDADES DE LOS HOGARES COMO EMPLEADORES DE PERSONAL DOMESTICO. ACTIVIDADES DE LOS HOGARES COMO PRODUCTORES DE BIENES Y SERVICIOS PARA USO PROPIO     8
#                            ACTIVIDADES FINANCIERAS Y DE SEGUROS                                                                                                                     9
#                            ACTIVIDADES INMOBILIARIAS                                                                                                                                8
# ...

# %%
maestro_cm23.groupby(['mes','actividad'])['valor'].mean()
# Out:
# mes  actividad
# 1    ACTIVIDADES ADMINISTRATIVAS Y SERVICIOS AUXILIARES                                                                                                       133.384306
#      ACTIVIDADES ARTISTICAS RECREATIVAS Y DE ENTRETENIMIENTO                                                                                                   31.456073
#      ACTIVIDADES DE LOS HOGARES COMO EMPLEADORES DE PERSONAL DOMESTICO. ACTIVIDADES DE LOS HOGARES COMO PRODUCTORES DE BIENES Y SERVICIOS PARA USO PROPIO      27.061481
#      ACTIVIDADES DE ORGANIZACIONES Y ORGANISMOS EXTRATERRITORIALES                                                                                              2.305085
#      ACTIVIDADES FINANCIERAS Y DE SEGUROS                                                                                                                      10.356688
# ...
