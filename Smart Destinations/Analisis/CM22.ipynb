# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import functools

# %% [markdown]
# # origen del suistentoo de los vicitantes

# %%
evolucion_cm22 = "../../../datos/CM22/maestro_cm22.csv"
evolucion_cm22 = pd.read_csv(evolucion_cm22)
evolucion_cm22.describe()
# Out:
#                anyo           mes         valor     valorPrev  ultima_fecha
# count  41340.000000  41340.000000  41171.000000  36948.000000       41340.0
# mean    2015.871795      7.538462    166.942304    166.531988      202103.0
# std        2.839134      3.388151   1140.441467   1136.845194           0.0
# min     2011.000000      3.000000      0.000000      0.000000      202103.0
# 25%     2013.000000      3.000000      8.000000      8.100000      202103.0
# 50%     2016.000000      9.000000     18.800000     18.800000      202103.0
# 75%     2018.000000     12.000000     69.600000     69.425000      202103.0
# max     2021.000000     12.000000  23491.900000  23491.900000      202103.0

# %%
evolucion_cm22
# Out:
#             provincia   actividad  anyo  mes    valor  valorPrev  \
# 0      Total Nacional  Total CNAE  2021    3  23215.5    21975.2
# 1      Total Nacional  Total CNAE  2020   12  22860.7    22994.2
# 2      Total Nacional  Total CNAE  2020    9  23064.1    23158.8
# 3      Total Nacional  Total CNAE  2020    6  22899.8    23088.7
# 4      Total Nacional  Total CNAE  2020    3  21975.2    23035.5
# ...               ...         ...   ...  ...      ...        ...
# 41335         Melilla   Servicios  2012    9     90.7       93.2
# 41336         Melilla   Servicios  2012    6     90.7        NaN
# 41337         Melilla   Servicios  2012    3     89.4        NaN
# 41338         Melilla   Servicios  2011   12     94.5        NaN
# 41339         Melilla   Servicios  2011    9     93.2        NaN
#
#                    Indicador  ultima_fecha
# 0                    Activos        202103
# 1                    Activos        202103
# 2                    Activos        202103
# ...

# %%
evolucion_cm22.groupby(['actividad', 'Indicador']).sum()
# Out:
#                                                                              anyo  \
# actividad                                          Indicador
# Agricultura                                        Activos                4166807
#                                                    Distribución Activos   4166807
#                                                    Distribución Ocupados  4166807
#                                                    Ocupados               4166807
# Construcción                                       Activos                4166807
#                                                    Distribución Activos   4166807
#                                                    Distribución Ocupados  4166807
#                                                    Ocupados               4166807
# Industria                                          Activos                4166807
#                                                    Distribución Activos   4166807
# ...
