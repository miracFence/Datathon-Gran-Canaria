# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import functools

# %%
maestro_cm09 = "../../datos/CM09/maestro_cm09.csv"
maestro_cm09_dt = pd.read_csv(maestro_cm09)
maestro_cm09_dt.head(35)
# Out:
#     Anyo      Valor  ValorPrev                                Indicador  \
# 0   2016        1.3        NaN                                      IPC
# 1   2017        1.1        1.3                                      IPC
# 2   2018        1.4        1.1                                      IPC
# 3   2016       -9.1        NaN                 IPI - Bienes intermedios
# 4   2017        3.7       -9.1                 IPI - Bienes intermedios
# 5   2018      -14.8        3.7                 IPI - Bienes intermedios
# 6   2016       18.2        NaN                  IPI - Bienes de consumo
# 7   2017        3.9       18.2                  IPI - Bienes de consumo
# 8   2018      -32.0        3.9                  IPI - Bienes de consumo
# 9   2011  3455397.0        0.0                   Recaudación tributaria
# 10  2016  4958493.0        0.0                   Recaudación tributaria
# 11  2017  5399386.0  4958493.0                   Recaudación tributaria
# ...

# %%
maestro_cm09_dt.groupby(['Anyo','Indicador', 'ultima_fecha']).sum()
# Out:
#                                                                Valor  \
# Anyo Indicador                               ultima_fecha
# 2007 Exportaciones                           2018          3223403.0
#      Exportaciones derivadas del petróleo    2018          1266958.0
#      Exportaciones no derivadas del petróleo 2018          1956445.0
# 2011 Impuestos directos                      2018          1814222.0
#      Impuestos indirectos                    2018          1592653.0
#      Recaudación tributaria                  2018          3455397.0
#      Tasas y otros                           2018            48522.0
# 2016 IPC                                     2018                1.3
#      IPI - Bienes de consumo                 2018               18.2
#      IPI - Bienes intermedios                2018               -9.1
#      Impuestos directos                      2018          2133064.0
#      Impuestos indirectos                    2018          2765864.0
# ...
