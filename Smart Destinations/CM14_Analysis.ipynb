# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import functools

# %%
maestro_cm14 = "../../datos/CM14/maestro_cm_4.csv"
geomap_cm14 = "../../datos/CM14/geomap_cm_4.csv"
maestro_cm14_dt = pd.read_csv(maestro_cm14)
geomap_cm14_dt = pd.read_csv(geomap_cm14)

geomap_clean = geomap_cm14_dt.rename(columns = {'dimension_': 'dimension', 'residencia_': 'residencia', 'codigo_pais_': 'codigo_pais'}, inplace = False)

combined_cm14_dt = pd.concat([maestro_cm14_dt, geomap_clean])
combined_cm14_dt
# Out:
#            indicador dimension       residencia codigo_pais  anyo  mes  \
# 0           Viajeros  Regiones            Total         NaN  2021    3
# 1           Viajeros  Regiones            Total         NaN  2021    2
# 2           Viajeros  Regiones            Total         NaN  2021    1
# 3           Viajeros  Regiones            Total         NaN  2020   12
# 4           Viajeros  Regiones            Total         NaN  2020   11
# ...              ...       ...              ...         ...   ...  ...
# 7247  Pernoctaciones  Regiones  Resto del mundo         NaN  2011    8
# 7248  Pernoctaciones  Regiones  Resto del mundo         NaN  2011    7
# 7249  Pernoctaciones  Regiones  Resto del mundo         NaN  2011    6
# 7250  Pernoctaciones  Regiones  Resto del mundo         NaN  2011    5
# 7251  Pernoctaciones  Regiones  Resto del mundo         NaN  2011    4
#
#           valor  valorPrev       total     fecha  ultima_fecha
# 0     1735172.0  2656776.0   1735172.0  20210331      20210331
# 1     1152795.0  6456402.0   1152795.0  20210228      20210331
# 2     1092017.0  5577618.0   1092017.0  20210131      20210331
# 3     1397664.0  6240788.0   1397664.0  20201231      20210331
# 4     1171282.0  6693210.0   1171282.0  20201130      20210331
# ...         ...        ...         ...       ...           ...
# 7247   533082.0        NaN  41694917.0  20110831      20210331
# 7248   621133.0        NaN  37980214.0  20110731      20210331
# 7249   498797.0        NaN  30704218.0  20110630      20210331
# 7250   461021.0        NaN  24670723.0  20110531      20210331
# 7251   385868.0        NaN  22618769.0  20110430      20210331
#
# [14504 rows x 11 columns]

# %%
combined_cm14_filtered = combined_cm14_dt.drop_duplicates()
combined_cm14_filtered
# Out:
#            indicador dimension       residencia codigo_pais  anyo  mes  \
# 0           Viajeros  Regiones            Total         NaN  2021    3
# 1           Viajeros  Regiones            Total         NaN  2021    2
# 2           Viajeros  Regiones            Total         NaN  2021    1
# 3           Viajeros  Regiones            Total         NaN  2020   12
# 4           Viajeros  Regiones            Total         NaN  2020   11
# ...              ...       ...              ...         ...   ...  ...
# 7247  Pernoctaciones  Regiones  Resto del mundo         NaN  2011    8
# 7248  Pernoctaciones  Regiones  Resto del mundo         NaN  2011    7
# 7249  Pernoctaciones  Regiones  Resto del mundo         NaN  2011    6
# 7250  Pernoctaciones  Regiones  Resto del mundo         NaN  2011    5
# 7251  Pernoctaciones  Regiones  Resto del mundo         NaN  2011    4
#
#           valor  valorPrev       total     fecha  ultima_fecha
# 0     1735172.0  2656776.0   1735172.0  20210331      20210331
# 1     1152795.0  6456402.0   1152795.0  20210228      20210331
# 2     1092017.0  5577618.0   1092017.0  20210131      20210331
# 3     1397664.0  6240788.0   1397664.0  20201231      20210331
# 4     1171282.0  6693210.0   1171282.0  20201130      20210331
# ...         ...        ...         ...       ...           ...
# 7247   533082.0        NaN  41694917.0  20110831      20210331
# 7248   621133.0        NaN  37980214.0  20110731      20210331
# 7249   498797.0        NaN  30704218.0  20110630      20210331
# 7250   461021.0        NaN  24670723.0  20110531      20210331
# 7251   385868.0        NaN  22618769.0  20110430      20210331
#
# [7252 rows x 11 columns]

# %%
combined_cm14_filtered['fecha'] = pd.to_datetime(combined_cm14_filtered['fecha'], format='%Y%m%d')
combined_cm14_filtered['ultima_fecha'] = pd.to_datetime(combined_cm14_filtered['ultima_fecha'], format='%Y%m%d')

combined_cm14_filtered.head(10)
# Out:
# <ipython-input-12-0a178ea68d2d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_cm14_filtered['fecha'] = pd.to_datetime(combined_cm14_filtered['fecha'], format='%Y%m%d')
# <ipython-input-12-0a178ea68d2d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_cm14_filtered['ultima_fecha'] = pd.to_datetime(combined_cm14_filtered['ultima_fecha'], format='%Y%m%d')
#   indicador dimension residencia codigo_pais  anyo  mes      valor  \
# 0  Viajeros  Regiones      Total         NaN  2021    3  1735172.0
# 1  Viajeros  Regiones      Total         NaN  2021    2  1152795.0
# 2  Viajeros  Regiones      Total         NaN  2021    1  1092017.0
# 3  Viajeros  Regiones      Total         NaN  2020   12  1397664.0
# 4  Viajeros  Regiones      Total         NaN  2020   11  1171282.0
# 5  Viajeros  Regiones      Total         NaN  2020   10  2393707.0
# 6  Viajeros  Regiones      Total         NaN  2020    9  3470747.0
# 7  Viajeros  Regiones      Total         NaN  2020    8  5892395.0
# 8  Viajeros  Regiones      Total         NaN  2020    7  4330564.0
# 9  Viajeros  Regiones      Total         NaN  2020    6   920778.0
#
#     valorPrev      total      fecha ultima_fecha
# 0   2656776.0  1735172.0 2021-03-31   2021-03-31
# 1   6456402.0  1152795.0 2021-02-28   2021-03-31
# 2   5577618.0  1092017.0 2021-01-31   2021-03-31
# 3   6240788.0  1397664.0 2020-12-31   2021-03-31
# 4   6693210.0  1171282.0 2020-11-30   2021-03-31
# 5   9772631.0  2393707.0 2020-10-31   2021-03-31
# 6  11038778.0  3470747.0 2020-09-30   2021-03-31
# 7  13028096.0  5892395.0 2020-08-31   2021-03-31
# 8  12124664.0  4330564.0 2020-07-31   2021-03-31
# 9  11371775.0   920778.0 2020-06-30   2021-03-31

# %%
combined_cm14_filtered['codigo_pais'] = combined_cm14_filtered['codigo_pais'].fillna('NON-ID')
combined_cm14_filtered
# Out:
# <ipython-input-17-26c2f48e4e7b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_cm14_filtered['codigo_pais'] = combined_cm14_filtered['codigo_pais'].fillna('NON-ID')
#            indicador dimension       residencia codigo_pais  anyo  mes  \
# 0           Viajeros  Regiones            Total      NON-ID  2021    3
# 1           Viajeros  Regiones            Total      NON-ID  2021    2
# 2           Viajeros  Regiones            Total      NON-ID  2021    1
# 3           Viajeros  Regiones            Total      NON-ID  2020   12
# 4           Viajeros  Regiones            Total      NON-ID  2020   11
# ...              ...       ...              ...         ...   ...  ...
# 7247  Pernoctaciones  Regiones  Resto del mundo      NON-ID  2011    8
# 7248  Pernoctaciones  Regiones  Resto del mundo      NON-ID  2011    7
# 7249  Pernoctaciones  Regiones  Resto del mundo      NON-ID  2011    6
# 7250  Pernoctaciones  Regiones  Resto del mundo      NON-ID  2011    5
# 7251  Pernoctaciones  Regiones  Resto del mundo      NON-ID  2011    4
#
#           valor  valorPrev       total      fecha ultima_fecha
# 0     1735172.0  2656776.0   1735172.0 2021-03-31   2021-03-31
# 1     1152795.0  6456402.0   1152795.0 2021-02-28   2021-03-31
# 2     1092017.0  5577618.0   1092017.0 2021-01-31   2021-03-31
# 3     1397664.0  6240788.0   1397664.0 2020-12-31   2021-03-31
# 4     1171282.0  6693210.0   1171282.0 2020-11-30   2021-03-31
# ...         ...        ...         ...        ...          ...
# 7247   533082.0        NaN  41694917.0 2011-08-31   2021-03-31
# 7248   621133.0        NaN  37980214.0 2011-07-31   2021-03-31
# 7249   498797.0        NaN  30704218.0 2011-06-30   2021-03-31
# 7250   461021.0        NaN  24670723.0 2011-05-31   2021-03-31
# 7251   385868.0        NaN  22618769.0 2011-04-30   2021-03-31
#
# [7252 rows x 11 columns]

# %%
combined_cm14_filtered.groupby('indicador', as_index=False)['total'].mean()
# Out:
#         indicador         total
# 0  Pernoctaciones  2.383853e+07
# 1        Viajeros  7.275235e+06

# %%
combined_cm14_filtered.groupby('indicador', as_index=False)['total'].mean()

# %%
combined_cm14_filtered.groupby('residencia', as_index=False)['total'].mean()
# Out:
#                         residencia         total
# 0                         Alemania  1.559019e+07
# 1                          Austria  1.559019e+07
# 2                          Bélgica  1.559019e+07
# 3                        Dinamarca  1.559019e+07
# 4                   Estados Unidos  1.559019e+07
# 5                        Finlandia  1.559019e+07
# 6                          Francia  1.559019e+07
# 7                           Grecia  1.559019e+07
# 8                          Irlanda  1.559019e+07
# 9                           Italia  1.559019e+07
# 10                           Japón  1.559019e+07
# 11                      Luxemburgo  1.559019e+07
# 12                         Noruega  1.559019e+07
# 13           Otros países europeos  1.559019e+07
# 14                    Países Bajos  1.559019e+07
# 15                Países africanos  1.559019e+07
# 16                         Polonia  1.559019e+07
# 17                        Portugal  1.559019e+07
# 18                     Reino Unido  1.559019e+07
# 19                 República Checa  1.559019e+07
# 20            Residentes en España  1.559019e+07
# 21     Residentes en el extranjero  1.559019e+07
# 22     Resto América Central y Sur  1.559019e+07
# 23                 Resto de la U.E  1.559019e+07
# 24                 Resto del mundo  1.559019e+07
# 25                           Rusia  1.559019e+07
# 26                          Suecia  1.559019e+07
# 27           Suiza y Liechtenstein  1.559019e+07
# 28                           Total  1.559019e+07
# 29  UE27_2020 sin España.Dato base  1.094555e+07
# 30      Unión Europea (sin España)  1.559019e+07

# %%
combined_cm14_filtered.groupby('codigo_pais', as_index=False)['total'].mean()
# Out:
#    codigo_pais         total
# 0           AT  1.559019e+07
# 1           BE  1.559019e+07
# 2           CH  1.559019e+07
# 3           CZ  1.559019e+07
# 4           DE  1.559019e+07
# 5           DK  1.559019e+07
# 6           ES  1.559019e+07
# 7           FI  1.559019e+07
# 8           FR  1.559019e+07
# 9           GB  1.559019e+07
# 10          GR  1.559019e+07
# 11          IE  1.559019e+07
# 12          IT  1.559019e+07
# 13          JP  1.559019e+07
# 14          LU  1.559019e+07
# 15          NL  1.559019e+07
# 16          NO  1.559019e+07
# 17      NON-ID  1.546771e+07
# 18          PL  1.559019e+07
# 19          PT  1.559019e+07
# 20          RU  1.559019e+07
# 21          SE  1.559019e+07
# 22          US  1.559019e+07

# %%
combined_cm14_filtered.groupby(['anyo','mes'], as_index=False)['total'].mean()
# Out:
#     anyo         total
# 0   2011  1.739053e+07
# 1   2012  1.515092e+07
# 2   2013  1.541046e+07
# 3   2014  1.596146e+07
# 4   2015  1.672720e+07
# 5   2016  1.795871e+07
# 6   2017  1.851612e+07
# 7   2018  1.855385e+07
# 8   2019  1.884407e+07
# 9   2020  5.247286e+06
# 10  2021  2.046637e+06
